# %%
# !python DataGenerator.py --animal Macaque --data_directory Data --config config1.json --os Ubuntu --objective Classification --regime Closed

# %%
# !python DataGenerator.py --animal Macaque --data_directory Data --config config1.json --os Ubuntu --objective Separation --regime Closed
# Out:
# ...
# 100%|███████████████████████████████████████| 3000/3000 [01:55<00:00, 26.01it/s]

# %%
# !python Classifier.py -a Macaque -d Data -c config1.json
# Out:
#   0%|                                                   | 0/365 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
# 100%|█████████████████████████████████████████| 365/365 [00:54<00:00,  6.68it/s]
# Epoch: 1
#      >>>>> Train nll_loss: 1.07282
#      >>>>> Val nll_loss: 0.55707
#      >>>>> Train accuracy: 61.85788 --- Val accuracy: 79.07609
#      >>>>> 59s: 6.19it/s
# 100%|█████████████████████████████████████████| 365/365 [00:54<00:00,  6.68it/s]
# Epoch: 2
#      >>>>> Train nll_loss: 0.5741
#      >>>>> Val nll_loss: 0.38354
#      >>>>> Train accuracy: 80.47945 --- Val accuracy: 86.31114
#      >>>>> 59s: 6.19it/s
# ...

# %%
# !python Separator.py -a Macaque -d Data -c config1.json -cn saver_epoch44 -cpa 99.25272
# Out:
# Running Experiment
#   0%|                                                   | 0/750 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
# /opt/conda/lib/python3.7/site-packages/torch/functional.py:655: UserWarning: istft will require a complex-valued input tensor in a future PyTorch release. Matching the output from stft with return_complex=True.  (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:787.)
#   normalized, onesided, length, return_complex)
# 100%|█████████████████████████████████████████| 750/750 [08:54<00:00,  1.40it/s]
# Epoch: 1
#      >>>>> Train pit_multi_loss: 0.0578
#      >>>>> Val pit_multi_loss: 0.04963
# ...
