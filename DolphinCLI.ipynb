# %%
# !python DataGenerator.py --animal Dolphin --data_directory Data --config configHPF.json --os Ubuntu --objective Classification --regime Closed

# %%
# !python DataGenerator.py --animal Dolphin --data_directory Data --config configHPF.json --os Ubuntu --objective Separation --regime Closed
# Out:
# ...
# 100%|███████████████████████████████████████| 2000/2000 [06:06<00:00,  5.45it/s]

# %%
# !python Classifier.py -a Dolphin -d Data -c configHPF.json
# Out:
#   0%|                                                   | 0/256 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
# 100%|█████████████████████████████████████████| 256/256 [00:29<00:00,  8.70it/s]
# Epoch: 1
#      >>>>> Train nll_loss: 1.85908
#      >>>>> Val nll_loss: 1.65421
#      >>>>> Train accuracy: 25.14648 --- Val accuracy: 34.2803
#      >>>>> 32s: 8.0it/s
# 100%|█████████████████████████████████████████| 256/256 [00:29<00:00,  8.72it/s]
# Epoch: 2
#      >>>>> Train nll_loss: 1.27515
#      >>>>> Val nll_loss: 0.8359
#      >>>>> Train accuracy: 48.29102 --- Val accuracy: 74.24242
#      >>>>> 32s: 8.0it/s
# ...

# %%
# !python Separator.py -a Dolphin -d Data -c configHPF.json -cn saver_epoch50 -cpa 99.43182
# Out:
# Running Experiment
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
# /opt/conda/lib/python3.7/site-packages/torch/functional.py:655: UserWarning: istft will require a complex-valued input tensor in a future PyTorch release. Matching the output from stft with return_complex=True.  (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:787.)
#   normalized, onesided, length, return_complex)
# 100%|███████████████████████████████████████| 1000/1000 [14:13<00:00,  1.17it/s]
# Epoch: 1
#      >>>>> Train pit_multi_loss: 0.04646
#      >>>>> Val pit_multi_loss: 0.03937
# ...

# %%
# !python Separator.py -a Dolphin -d Data -c configHPF.json -cn saver_epoch45 -cpa 99.05303
# Out:
# Running Experiment
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
# /opt/conda/lib/python3.7/site-packages/torch/functional.py:655: UserWarning: istft will require a complex-valued input tensor in a future PyTorch release. Matching the output from stft with return_complex=True.  (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:787.)
#   normalized, onesided, length, return_complex)
# 100%|███████████████████████████████████████| 1000/1000 [15:17<00:00,  1.09it/s]
# Epoch: 1
#      >>>>> Train pit_multi_loss: 0.04282
#      >>>>> Val pit_multi_loss: 0.03667
# ...
