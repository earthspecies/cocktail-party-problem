# %%
from VisualizationsAndDemonstrations import audio_visual

# %% [markdown]
# # Macaques

# %% [markdown]
# ## 2 Speaker

# %% [markdown]
# ### Time Domain

# %%
audio_visual(animal='Macaque', 
             n_src=2,
             rep='WF',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# ### Time-Frequency Domain

# %%
audio_visual(animal='Macaque', 
             n_src=2,
             rep='TFR',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# ## 3 Speaker

# %% [markdown]
# ### Time Domain

# %%
audio_visual(animal='Macaque', 
             n_src=3,
             rep='WF',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# ### Time-Frequency Domain

# %%
audio_visual(animal='Macaque', 
             n_src=3,
             rep='TFR',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# # Dolphins

# %% [markdown]
# ## Time Domain

# %%
audio_visual(animal='Dolphin', 
             n_src=2,
             rep='WF',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# ### Time-Frequency Domain

# %%
audio_visual(animal='Dolphin', 
             n_src=2,
             rep='TFR',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# # Bats

# %% [markdown]
# ## Time Domain

# %%
audio_visual(animal='Bat', 
             n_src=2,
             rep='WF',
             playback_factor=1,
             directory='Assets')

# %% [markdown]
# ## Time-Frequency Domain

# %%
audio_visual(animal='Bat', 
             n_src=2,
             rep='TFR',
             playback_factor=1,
             directory='Assets')
